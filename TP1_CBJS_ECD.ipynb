# %% [markdown]
# # Team Project 1

# %% [markdown]
# ## Eli Dalton and Caitlin Sizemore

# %% [markdown]
# ### DS 160-01 Spring 2023

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vg_sales=pd.read_csv("vgsales.csv")

# %%
vg=vg_sales.head(50)

# %%
vg.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vg.sample(10)
# Out:
#     Rank                       Name Platform    Year       Genre  \
# 44    45         Grand Theft Auto V      PS4  2014.0      Action
# 38    39       Grand Theft Auto III      PS2  2001.0      Action
# 33    34  Call of Duty: Black Ops 3      PS4  2015.0     Shooter
# 9     10                  Duck Hunt      NES  1984.0     Shooter
# 13    14                    Wii Fit      Wii  2007.0      Sports
# 40    41    Call of Duty: Black Ops      PS3  2010.0     Shooter
# 10    11                 Nintendogs       DS  2005.0  Simulation
# 43    44                     Halo 3     X360  2007.0     Shooter
# 8      9  New Super Mario Bros. Wii      Wii  2009.0    Platform
# 28    29     Gran Turismo 3: A-Spec      PS2  2001.0      Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 44         Take-Two Interactive      3.80      5.81      0.36         2.02
# 38         Take-Two Interactive      6.99      4.51      0.30         1.30
# ...

# %%
vg.drop(['Rank'],axis=1, inplace=True)
# Out:
# /var/folders/d7/d5792h3s5yq4wcyjjr626k_w0000gn/T/ipykernel_54220/2922306637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vg.drop(['Rank'],axis=1, inplace=True)

# %%
vg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          50 non-null     object
#  1   Platform      50 non-null     object
#  2   Year          50 non-null     float64
#  3   Genre         50 non-null     object
#  4   Publisher     50 non-null     object
#  5   NA_Sales      50 non-null     float64
#  6   EU_Sales      50 non-null     float64
#  7   JP_Sales      50 non-null     float64
#  8   Other_Sales   50 non-null     float64
#  9   Global_Sales  50 non-null     float64
# dtypes: float64(6), object(4)
# memory usage: 4.0+ KB

# %%
vg.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# ## Summary Statistics

# %%
categorical=['Name', 'Platform', 'Genre', 'Publisher']

# %%
continuous=['Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# %%
vg.describe()
# Out:
#               Year   NA_Sales   EU_Sales   JP_Sales  Other_Sales  Global_Sales
# count    50.000000  50.000000  50.000000  50.000000    50.000000     50.000000
# mean   2004.760000   9.829800   5.688400   2.810800     1.894200     20.222800
# std       7.872867   7.156443   4.368159   2.366692     1.995781     11.575082
# min    1984.000000   2.550000   0.010000   0.060000     0.230000     11.330000
# 25%    2002.000000   5.800000   3.460000   0.472500     0.775000     13.472500
# 50%    2006.500000   8.330000   4.515000   2.800000     1.295000     16.000000
# 75%    2010.000000  10.575000   6.840000   4.175000     2.125000     23.005000
# max    2015.000000  41.490000  29.020000  10.220000    10.570000     82.740000

# %%
name=vg['Name'].value_counts()
name
# Out:
# Grand Theft Auto V                              3
# Call of Duty: Black Ops II                      2
# Call of Duty: Modern Warfare 3                  2
# Call of Duty: Black Ops                         2
# Wii Sports                                      1
# Pokemon Black/Pokemon White                     1
# Brain Age 2: More Training in Minutes a Day     1
# Gran Turismo 3: A-Spec                          1
# Pokémon Yellow: Special Pikachu Edition         1
# Pokemon X/Pokemon Y                             1
# Call of Duty: Black Ops 3                       1
# Call of Duty: Modern Warfare 2                  1
# Grand Theft Auto: Vice City                     1
# Grand Theft Auto III                            1
# Super Smash Bros. Brawl                         1
# Animal Crossing: Wild World                     1
# Mario Kart 7                                    1
# Halo 3                                          1
# Pokemon HeartGold/Pokemon SoulSilver            1
# ...

# %%
platform=vg['Platform'].value_counts()
platform
# Out:
# Wii     9
# DS      9
# X360    7
# GB      5
# PS2     5
# PS3     4
# NES     3
# 3DS     3
# PS4     2
# SNES    1
# GBA     1
# N64     1
# Name: Platform, dtype: int64

# %%
genre=vg['Genre'].value_counts()
genre
# Out:
# Shooter         10
# Platform         8
# Role-Playing     8
# Action           7
# Racing           5
# Sports           4
# Misc             3
# Puzzle           2
# Simulation       2
# Fighting         1
# Name: Genre, dtype: int64

# %%
publisher=vg['Publisher'].value_counts()
publisher
# Out:
# Nintendo                       32
# Activision                      8
# Take-Two Interactive            6
# Microsoft Game Studios          2
# Sony Computer Entertainment     2
# Name: Publisher, dtype: int64

# %% [markdown]
# ## Correlation Tables

# %%
vg.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
heat_map_corr=vg[['Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].corr(method='pearson')
print(heat_map_corr)

cols=['Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

heat_map=sns.heatmap(heat_map_corr, annot=True, xticklabels=cols, yticklabels=cols, cmap='BuPu')
# Out:
#                   Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Year          1.000000 -0.437198  0.196077 -0.352498     0.204647
# NA_Sales     -0.437198  1.000000  0.519829  0.150437     0.254122
# EU_Sales      0.196077  0.519829  1.000000  0.194564     0.397974
# JP_Sales     -0.352498  0.150437  0.194564  1.000000    -0.182604
# Other_Sales   0.204647  0.254122  0.397974 -0.182604     1.000000
# Global_Sales -0.233104  0.889022  0.807178  0.339467     0.442478
#
#               Global_Sales
# Year             -0.233104
# NA_Sales          0.889022
# EU_Sales          0.807178
# JP_Sales          0.339467
# Other_Sales       0.442478
# Global_Sales      1.000000

# %% [markdown]
# ## Graphical Exploration

# %%
vg.columns
# Out:
# Index(['Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
hist_plot=sns.histplot(x='Year', data=vg)

# %%
genre.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
platform.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
publisher.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
pair_plot=sns.pairplot(vg)

# %%
lm_plot=sns.lmplot(x='Year', y='NA_Sales', data=vg, hue='Genre', ci=False)

# %%
lm_plot=sns.lmplot(x='Global_Sales', y='NA_Sales', data=vg, hue='Genre', ci=False)

# %%
lm_plot=sns.lmplot(x='Year', y='NA_Sales', data=vg, hue='Platform', ci=False)

# %%
lm_plot=sns.lmplot(x='Global_Sales', y='NA_Sales', data=vg, hue='Platform', ci=False)

# %%
sns.set(rc={'figure.figsize':(12,6)})
bar_plot=sns.barplot(x='Publisher', y='Global_Sales', data=vg, ci=False)

# %%
sns.set(rc={'figure.figsize':(12,6)})
bar_plot=sns.barplot(x='Platform', y='Global_Sales', data=vg, ci=False)

# %%
sns.set(rc={'figure.figsize':(12,6)})
bar_plot=sns.barplot(x='Publisher', y='NA_Sales', data=vg, ci=False)

# %%
sns.set(rc={'figure.figsize':(12,6)})
bar_plot=sns.barplot(x='Platform', y='NA_Sales', data=vg, ci=False)

# %%
lm_plot=sns.lmplot(x='Global_Sales', y='NA_Sales', data=vg, hue='Name', ci=False)

# %%
box_plot=sns.boxplot(x='Platform', y='Global_Sales', data=vg)

# %%
box_plot=sns.boxplot(x='Platform', y='NA_Sales', data=vg)

# %%
scatter_plot=sns.scatterplot(x='Global_Sales', 
                             y='Platform', 
                             data=vg, 
                             color='red', 
                             hue='Publisher', 
                             style='Publisher')

# %%
scatter_plot=sns.scatterplot(x='NA_Sales', 
                             y='Platform', 
                             data=vg, 
                             color='red', 
                             hue='Publisher', 
                             style='Publisher')
